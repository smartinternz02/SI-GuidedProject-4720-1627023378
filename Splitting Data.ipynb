# %%
import splitfolders

# %%
splitfolders.ratio(r"D:\Smart Bridge\Project\Animals-10", output="data_set", seed=1337, ratio=(0.7, 0.3))
# Out:
# Copying files: 0 files [00:00, ? files/s]
#
#
# Copying files: 1 files [00:00,  4.99 files/s]
#
#
# Copying files: 75 files [00:00,  7.11 files/s]
#
#
# Copying files: 148 files [00:00, 10.11 files/s]
#
#
# Copying files: 222 files [00:00, 14.35 files/s]
#
#
# Copying files: 270 files [00:00, 20.15 files/s]
#
#
# Copying files: 347 files [00:00, 28.46 files/s]
#
#
# Copying files: 407 files [00:00, 39.84 files/s]
#
#
# Copying files: 484 files [00:00, 55.68 files/s]
#
#
# Copying files: 557 files [00:01, 77.01 files/s]
#
#
# Copying files: 625 files [00:01, 104.83 files/s]
#
#
# Copying files: 697 files [00:01, 140.90 files/s]
#
#
# Copying files: 768 files [00:01, 185.41 files/s]
#
#
# Copying files: 843 files [00:01, 239.32 files/s]
#
#
# Copying files: 916 files [00:01, 299.29 files/s]
#
#
# Copying files: 987 files [00:01, 362.00 files/s]
#
#
# Copying files: 1058 files [00:01, 422.71 files/s]
#
#
# Copying files: 1130 files [00:01, 481.76 files/s]
#
#
# ...
